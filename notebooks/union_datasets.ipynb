# %%
# Se van a unir los datos de contaminación y tráfico en un solo csv por mayor comoddidad

# Librerias y configuración

import warnings
import pandas as pd

warnings.filterwarnings('ignore')

# %%
# Carga de datos

df_traffic = pd.read_csv('../final_data/trafic_data.csv')

df_pollution = pd.read_csv('../final_data/pollution_data.csv')

# %%
# Unión de los datos

df = pd.merge(df_traffic, df_pollution, on=['fecha'], how='inner')

# %%
df.head()
# Out:
#    Unnamed: 0_x                fecha  intensidad  Unnamed: 0_y  \
# 0           904  2022-12-10 10:00:00   349.37503           226
# 1           904  2022-12-10 10:00:00   349.37503           970
# 2           904  2022-12-10 10:00:00   349.37503          1714
# 3           904  2022-12-10 10:00:00   349.37503          2458
# 4           904  2022-12-10 10:00:00   349.37503          3202
#
#                   estacion                 magnitud unidad_medida  valores
# 0         Escuelas Aguirre  Monóxido de Nitrógeno         ug/m3      3.0
# 1          Calle Farolillo   Dióxido de Nitrógeno         ug/m3     16.0
# 2          Pza. del Carmen    Óxidos de Nitrógeno         ug/m3     46.0
# 3          Méndez Álvaro   Dióxido de Nitrógeno         ug/m3     20.0
# 4  Urb. Embajada (Barajas)      Partículas < 10 um         ug/m3     13.0

# %%
# Se borran las columna unnamed

df.drop(columns=['Unnamed: 0_x', 'Unnamed: 0_y'], inplace=True)

# %%
df.head()
# Out:
#                  fecha  intensidad                 estacion  \
# 0  2022-12-10 10:00:00   349.37503         Escuelas Aguirre
# 1  2022-12-10 10:00:00   349.37503          Calle Farolillo
# 2  2022-12-10 10:00:00   349.37503          Pza. del Carmen
# 3  2022-12-10 10:00:00   349.37503          Méndez Álvaro
# 4  2022-12-10 10:00:00   349.37503  Urb. Embajada (Barajas)
#
#                   magnitud unidad_medida  valores
# 0  Monóxido de Nitrógeno         ug/m3      3.0
# 1   Dióxido de Nitrógeno         ug/m3     16.0
# 2    Óxidos de Nitrógeno         ug/m3     46.0
# 3   Dióxido de Nitrógeno         ug/m3     20.0
# 4      Partículas < 10 um         ug/m3     13.0

# %%
# Se guarda el csv

df.to_csv('../final_data/data.csv', index=False)
